# %% [markdown]
# ## Players who scored Test 100s most frequently
# Qualification: Top players ordered by Test hundreds (minimum 15 hundreds)

# %% [markdown]
# ### Load [espncricinfo's most test 100s](http://stats.espncricinfo.com/CI/content/records/227046.html) into a pandas dataframe

# %%
import pandas as pd

pd.set_option('display.max_rows', 100)

df = pd.read_html("https://www.espncricinfo.com/records/most-hundreds-in-a-career-227046")[0]

# %% [markdown]
# ### Obviously Tendulkar is on top

# %%
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (IND)  1989-2013  200   329  33  15921  248*  53.78
# 1         JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37
# 2           RT Ponting (AUS)  1995-2012  168   287  29  13378   257  51.85
# 3         KC Sangakkara (SL)  2000-2015  134   233  17  12400   319  57.40
# 4         R Dravid (ICC/IND)  1996-2012  164   286  32  13288   270  52.31
# 5          Younis Khan (PAK)  2000-2017  118   213  19  10099   313  52.05
# 6          SM Gavaskar (IND)  1971-1987  125   214  16  10122  236*  51.12
# 7           BC Lara (ICC/WI)  1990-2006  131   232   6  11953  400*  52.88
# 8      DPMD Jayawardene (SL)  1997-2014  149   252  15  11814   374  49.84
# 9              AN Cook (ENG)  2006-2018  161   291  16  12472   294  45.35
# 10        KS Williamson (NZ)  2010-2024  100   176  17   8743   251  54.98
# ...

# %% [markdown]
# ### Calculate innings per hundred
# Substract not outs from total innings (similar to calculating batting average)

# %%
df["inns_per_hundred"] = (df.Inns - df.NO) / df["100"]

# %% [markdown]
# ### Obvoiusly Bradman is on top now

# %%
df.sort_values("inns_per_hundred").reset_index(drop=True)
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1            CL Walcott (WI)  1948-1960   44    74   7   3798   220  56.68
# 2          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 3         KS Williamson (NZ)  2010-2024  100   176  17   8743   251  54.98
# 4             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 5            SPD Smith (AUS)  2010-2024  109   195  25   9685   239  56.97
# 6         JH Kallis (ICC/SA)  1995-2013  166   280  40  13289   224  55.37
# 7             GS Sobers (WI)  1954-1974   93   160  21   8032  365*  57.78
# 8          GS Chappell (AUS)  1970-1984   87   151  19   7110  247*  53.86
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10           ML Hayden (AUS)  1994-2009  103   184  14   8625   380  50.73
# ...

# %% [markdown]
# ### Draw the scatterplot
# X-Axis: Number of 100s,
# Y-Axis: Innings per 100

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

df["player_surname"] = df["Player"].str.split(" ").str[1]

hundreds = df["100"]
inns_per_hundred = df["inns_per_hundred"]
player = df["player_surname"]

plt.figure(figsize=(25, 25))
plt.scatter(hundreds, inns_per_hundred)

for label, x, y in zip(player, hundreds, inns_per_hundred):
    plt.annotate(label, xy = (x + 0.2, y), fontsize = 10)
